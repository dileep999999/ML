# %% [markdown]
# <a href="https://colab.research.google.com/github/dileep999999/ML/blob/main/linearandmultipleRegressionPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("/content/sample_data/hiring.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.experience = df.experience.fillna(0)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0          0                    8.0                           9      50000
# 1          0                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=ecc3bb4cf14e025971e8ee7fbd577e5c710530245de7b9b915ec7b5b4acf03f6
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
from word2number import w2n
df.experience[2:] = df.experience[2:].apply(w2n.word_to_num)
df
# Out:
# <ipython-input-7-dc1e9a3a023e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.experience[2:] = df.experience[2:].apply(w2n.word_to_num)
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0          0                    8.0                           9      50000
# 1          0                    8.0                           6      45000
# 2          5                    6.0                           7      60000
# 3          2                   10.0                          10      65000
# 4          7                    9.0                           6      70000
# 5          3                    7.0                          10      62000
# 6         10                    NaN                           7      72000
# ...

# %%
median_test_score = df['test_score(out of 10)'].median()
median_test_score
# Out:
# 8.0

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(median_test_score)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0          0                    8.0                           9      50000
# 1          0                    8.0                           6      45000
# 2          5                    6.0                           7      60000
# 3          2                   10.0                          10      65000
# 4          7                    9.0                           6      70000
# 5          3                    7.0                          10      62000
# 6         10                    8.0                           7      72000
# 7         11                    7.0                           8      80000

# %%
X = df.drop('salary($)',axis='columns')
X
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)
# 0          0                    8.0                           9
# 1          0                    8.0                           6
# 2          5                    6.0                           7
# 3          2                   10.0                          10
# 4          7                    9.0                           6
# 5          3                    7.0                          10
# 6         10                    8.0                           7
# 7         11                    7.0                           8

# %%
y=df['salary($)']
y
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
linear = linear_model.LinearRegression()
linear.fit(X,y)
# Out:
# LinearRegression()

# %%
linear.predict([[12,10.0,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])

# %%
linear.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
linear.intercept_
# Out:
# 17737.263464337688
